# %%
import c

# %%
chat_int = c.ChatBotInterface("""Real Albert Einstein""")
# Out:
# Prompt ##########################
#
# full frontal face, complete facial view, no obstructions, close-up portrait, realistic Albert Einstein, white hair, bushy mustache, piercing eyes, intelligent gaze, iconic appearance, scientific genius, best quality, highly detailed, perfect lighting, masterpiece, extremely detailed face, detailed eyes, 8K High definition, Ultra Detailed, High quality texture, intricate details, detailed texture, finely detailed, high detail, extremely detailed cg, High quality shadow, Depth of field, Ray tracing, ultra realistic, authentic representation, true likeness
#
# Neg Prompt ######################
#
# partial face, side view, cropped face, profile view, full body, distant, NSFW, cartoon, lowres, bad anatomy, text, error, missing facial features, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, artist name, young, loli, elf, 3d, illustration ng_deepnegative_v1_75t, low quality face, low quality eyes, low quality body, low detail clothes
# Written to s3://aigc-bj-team1/bot_img.png

# %%
chat_int.ttv.download("bot_img.png", "/root/chatbotTOpolly/bot_img.png")
# Out:
# Download to /root/chatbotTOpolly/bot_img.png

# %%
def get_bot(desc):
    interface = c.ChatBotInterface(desc)
    path = interface.bot_img_local
    return path

# %%
import gradio as gr


with gr.Blocks() as demo:
    name = gr.Textbox(label="Character Description")
    output = gr.Image(type="filepath")
    greet_btn = gr.Button("Generate")
    greet_btn.click(fn=get_bot, inputs=name, outputs=output)
demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7865
# Sagemaker notebooks may require sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Running on public URL: https://dd809b9b0a4953f382.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://dd809b9b0a4953f382.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
